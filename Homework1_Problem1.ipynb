# %% [markdown]
# <a href="https://colab.research.google.com/github/hurricane195/Intro-to-Machine-Learning/blob/Homework-1/Homework1_Problem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#using a modified version of Dr. Tabkhi's "LinearRegression" code found at: https://github.com/HamedTabkhi/Intro-to-ML/blob/main/IntroCodes/LinearRegression.ipynb

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/hurricane195/Intro-to-Machine-Learning/Homework-1/D3.csv'

df = pd.read_csv(url)

# Display the first 5 rows of the DataFrame
print(df.head())
# Out:
#          X1        X2        X3         Y
# 0  0.000000  3.440000  0.440000  4.387545
# 1  0.040404  0.134949  0.888485  2.679650
# 2  0.080808  0.829899  1.336970  2.968490
# 3  0.121212  1.524848  1.785455  3.254065
# 4  0.161616  2.219798  2.233939  3.536375

# %%
# Separate features and labels
X1 = df.values[:,0]  # get input values from first column -- X1 is a list here
y = df.values[:, 3]  # get output values from fourth column -- Y is the list here
m = len(y)  # Number of training examples
n1 = len(X1)  # Number of training examples


# Display first 5 records and the total number of training examples
print('X1 = ', X1[: 5])
print('y = ', y[: 5])
print('m = ', m)
print('n1 = ', n1)
print('')

# Separate features and labels
X2 = df.values[:,1]  # get input values from second column -- X2 is a list here
y = df.values[:, 3]  # get output values from fourth column -- Y is the list here
m = len(y)  # Number of training examples
n2 = len(X2)  # Number of training examples


# Display first 5 records and the total number of training examples
print('X2 = ', X2[: 5])
print('y = ', y[: 5])
print('m = ', m)
print('n2 = ', n2)
print('')

# Separate features and labels
X3 = df.values[:,2]  # get input values from second column -- X3 is a list here
y = df.values[:, 3]  # get output values from fourth column -- Y is the list here
m = len(y)  # Number of training examples
n3 = len(X3)  # Number of training examples

# Display first 5 records and the total number of training examples
print('X3 = ', X3[: 5])
print('y = ', y[: 5])
print('m = ', m)
print('n3 = ', n3)
print('')
# Out:
# X1 =  [0.         0.04040404 0.08080808 0.12121212 0.16161616]
# y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100
# n1 =  100
#
# X2 =  [3.44       0.1349495  0.82989899 1.52484848 2.21979798]
# y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100
# n2 =  100
#
# X3 =  [0.44       0.88848485 1.3369697  1.78545454 2.23393939]
# y =  [4.38754501 2.6796499  2.96848981 3.25406475 3.53637472]
# m =  100
# n3 =  100

# %%
print('X1 = ', X1[: 100])
print('y = ', y[: 100])
print('')

print('X2 = ', X2[: 100])
print('y = ', y[: 100])
print('')

print('X3 = ', X3[: 100])
print('y = ', y[: 100])
print('')
# Out:
# X1 =  [0.         0.04040404 0.08080808 0.12121212 0.16161616 0.2020202
#  0.24242424 0.28282828 0.32323232 0.36363636 0.4040404  0.44444444
#  0.48484848 0.52525252 0.56565657 0.60606061 0.64646465 0.68686869
#  0.72727273 0.76767677 0.80808081 0.84848485 0.88888889 0.92929293
#  0.96969697 1.01010101 1.05050505 1.09090909 1.13131313 1.17171717
#  1.21212121 1.25252525 1.29292929 1.33333333 1.37373737 1.41414141
#  1.45454546 1.49494949 1.53535354 1.57575758 1.61616162 1.65656566
#  1.6969697  1.73737374 1.77777778 1.81818182 1.85858586 1.8989899
#  1.93939394 1.97979798 2.02020202 2.06060606 2.1010101  2.14141414
#  2.18181818 2.22222222 2.26262626 2.3030303  2.34343434 2.38383838
#  2.42424242 2.46464646 2.5050505  2.54545455 2.58585859 2.62626263
#  2.66666667 2.70707071 2.74747475 2.78787879 2.82828283 2.86868687
#  2.90909091 2.94949495 2.98989899 3.03030303 3.07070707 3.11111111
#  3.15151515 3.19191919 3.23232323 3.27272727 3.31313131 3.35353535
# ...

# %%
from IPython.display import display
display(df)
# Out:
#           X1        X2        X3         Y
# 0   0.000000  3.440000  0.440000  4.387545
# 1   0.040404  0.134949  0.888485  2.679650
# 2   0.080808  0.829899  1.336970  2.968490
# 3   0.121212  1.524848  1.785455  3.254065
# 4   0.161616  2.219798  2.233939  3.536375
# ..       ...       ...       ...       ...
# 95  3.838384  1.460202  3.046061 -4.440595
# 96  3.878788  2.155152  3.494545 -4.458663
# 97  3.919192  2.850101  3.943030 -4.479995
# 98  3.959596  3.545051  0.391515 -3.304593
# 99  4.000000  0.240000  0.840000 -5.332455
#
# [100 rows x 4 columns]

# %%
X1 = df.values[:,0]  # get input values from the first column -- X1 is a list here which is a 1 dimentional array
y = df.values[:, 3]  # get output values from the fourth column --  Y is a list here which is a 2 dimentional array

# Scatter plot
plt.scatter(X1, y, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Scatter plot of training data for X1')

# Show the plot
plt.show()
print('')

X2 = df.values[:,1]  # get input values from the second column -- X2 is a list here which is a 1 dimentional array
y = df.values[:, 3]  # get output values from the fourth column --  Y is a list here which is a 2 dimentional array

# Scatter plot
plt.scatter(X2, y, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.xlabel('X2')
plt.ylabel('Y')
plt.title('Scatter plot of training data for X2')

# Show the plot
plt.show()
print('')

X3 = df.values[:,2]  # get input values from the third column -- X3 is a list here which is a 1 dimentional array
y = df.values[:, 3]  # get output values from the second column --  Y is a list here which is a 2 dimentional array

# Scatter plot
plt.scatter(X3, y, color='red', marker='+')

# Grid, labels, and title
plt.grid(True)
plt.rcParams["figure.figsize"] = (6, 6)
plt.xlabel('X3')
plt.ylabel('Y')
plt.title('Scatter plot of training data for X3')

# Show the plot
plt.show()
print('')

# %%
#We walk through the initial steps of building a linear regression model from scratch using NumPy. Let's break down what you're doing:
#X_0 = np.ones((m, 1)): We're creating a column vector of ones. This will be used as the "bias" term for the linear regression model.
#X_1 = X.reshape(m, 1): You're reshaping features (X) to make it a 2D array suitable for matrix operations.
#X = np.hstack((X_0, X_1)): We're horizontally stacking X_0 and X_1 to create final feature matrix X.

# %%
X_0 = np.ones((m, 1))
X_0[:5]
# Out:
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
X_1_1 = X1.reshape(m,1)
X_1_1[:10]
# Out:
# array([[0.        ],
#        [0.04040404],
#        [0.08080808],
#        [0.12121212],
#        [0.16161616],
#        [0.2020202 ],
#        [0.24242424],
#        [0.28282828],
#        [0.32323232],
#        [0.36363636]])

# %%
X_1_2 = X2.reshape(m, 1)
X_1_2[:10]
# Out:
# array([[3.44      ],
#        [0.1349495 ],
#        [0.82989899],
#        [1.52484848],
#        [2.21979798],
#        [2.91474747],
#        [3.60969697],
#        [0.30464646],
#        [0.99959596],
#        [1.69454546]])

# %%
X_1_3 = X3.reshape(m, 1)
X_1_3[:10]
# Out:
# array([[0.44      ],
#        [0.88848485],
#        [1.3369697 ],
#        [1.78545454],
#        [2.23393939],
#        [2.68242424],
#        [3.13090909],
#        [3.57939394],
#        [0.02787879],
#        [0.47636364]])

# %%
# Lets use hstack() function from numpy to stack X_0 with X_1_1, X_1_2 and X_1_3 horizontally (i.e. column
# This will be our final X matrix (feature matrix)
X1 = np.hstack((X_0, X_1_1))
X1[:5]
# Out:
# array([[1.        , 0.        ],
#        [1.        , 0.04040404],
#        [1.        , 0.08080808],
#        [1.        , 0.12121212],
#        [1.        , 0.16161616]])

# %%
X2 = np.hstack((X_0, X_1_2))
X2[:5]
# Out:
# array([[1.        , 3.44      ],
#        [1.        , 0.1349495 ],
#        [1.        , 0.82989899],
#        [1.        , 1.52484848],
#        [1.        , 2.21979798]])

# %%
X3 = np.hstack((X_0, X_1_3))
X3[:5]
# Out:
# array([[1.        , 0.44      ],
#        [1.        , 0.88848485],
#        [1.        , 1.3369697 ],
#        [1.        , 1.78545454],
#        [1.        , 2.23393939]])

# %%
theta1 = np.zeros(2)
theta1
# Out:
# array([0., 0.])

# %%
theta2 = np.zeros(2)
theta2
# Out:
# array([0., 0.])

# %%
theta3 = np.zeros(2)
theta3
# Out:
# array([0., 0.])

# %%
def compute_cost1(X1, y, theta1):

    """
    Compute cost for linear regression.

    Parameters:
    X : 2D array where each row represents the training example and each column represent the feature
        m = number of training examples
        n = number of features (including X_0 column of ones)
    y : 1D array of labels/target values for each training example. dimension(m)
    theta : 1D array of fitting parameters or weights. Dimension (n)

    Returns:
    J : Scalar value, the cost
    """
    predictions1 = X1.dot(theta1)
    errors1 = np.subtract(predictions1, y)
    sqrErrors1 = np.square(errors1)
    J1 = 1 / (2 * m) * np.sum(sqrErrors1)
    return J1

# %%
# Lets compute the cost1 for theta1 values
cost1 = compute_cost1(X1, y, theta1)
print('The cost1 for given values of theta_0_1 and theta_1_1 =', cost1)
# Out:
# The cost1 for given values of theta_0_1 and theta_1_1 = 5.524438459196242

# %%
def compute_cost2(X2, y, theta2):

    predictions2 = X2.dot(theta2)
    errors2 = np.subtract(predictions2, y)
    sqrErrors2 = np.square(errors2)
    J2 = 1 / (2 * m) * np.sum(sqrErrors2)
    return J2

# %%
# Lets compute the cost2 for theta2 values
cost2 = compute_cost2(X2, y, theta2)
print('The cost2 for given values of theta_0_2 and theta_1_2 =', cost2)
# Out:
# The cost2 for given values of theta_0_2 and theta_1_2 = 5.524438459196242

# %%
def compute_cost3(X3, y, theta3):

    predictions3 = X3.dot(theta3)
    errors3 = np.subtract(predictions3, y)
    sqrErrors3 = np.square(errors3)
    J3 = 1 / (2 * m) * np.sum(sqrErrors3)
    return J3

# %%
# Lets compute the cost3 for theta3 values
cost3 = compute_cost3(X3, y, theta3)
print('The cost3 for given values of theta_0_2 and theta_1_2 =', cost3)
# Out:
# The cost3 for given values of theta_0_2 and theta_1_2 = 5.524438459196242

# %%
def gradient_descent1(X1, y, theta1, alpha1, iterations1):
    """
    Compute the optimal parameters using gradient descent for linear regression.

    Parameters:
    X : 2D array where each row represents the training example and each column represents the feature
        m = number of training examples
        n = number of features (including X_0 column of ones)
    y : 1D array of labels/target values for each training example. dimension(m)
    theta : 1D array of fitting parameters or weights. Dimension (n)
    alpha : Learning rate (scalar)
    iterations : Number of iterations (scalar)

    Returns:
    theta : Updated values of fitting parameters or weights after 'iterations' iterations. Dimension (n)
    cost_history : Array containing the cost for each iteration. Dimension (iterations)
    """

    m = len(y)  # Number of training examples
    cost_history1 = np.zeros(iterations1)

    for i in range(iterations1):
        predictions1 = X1.dot(theta1)
        errors1 = np.subtract(predictions1, y)
        sum_delta1 = (alpha1 / m) * X1.transpose().dot(errors1)
        theta1 -= sum_delta1
        cost_history1[i] = compute_cost1(X1, y, theta1)

    return theta1, cost_history1

# %%
theta1 = [0., 0.]
iterations1 = 1500
alpha1 = 0.01

# %%
theta1, cost_history1 = gradient_descent1(X1, y, theta1, alpha1, iterations1)
print('Final value of theta1 =', theta1)
print('cost_history1 =', cost_history1)
# Out:
# Final value of theta1 = [ 5.71850653 -1.9568206 ]
# cost_history1 = [5.48226715 5.44290965 5.40604087 ... 0.99063932 0.99061433 0.99058944]

# %%
def gradient_descent2(X2, y, theta2, alpha2, iterations2):

    m = len(y)  # Number of training examples
    cost_history2 = np.zeros(iterations2)

    for i in range(iterations2):
        predictions2 = X2.dot(theta2)
        errors2 = np.subtract(predictions2, y)
        sum_delta2 = (alpha2 / m) * X2.transpose().dot(errors2)
        theta2 -= sum_delta2
        cost_history2[i] = compute_cost2(X2, y, theta2)

    return theta2, cost_history2

# %%
theta2 = [0., 0.]
iterations2 = 1500
alpha2 = 0.01

# %%
theta2, cost_history2 = gradient_descent2(X2, y, theta2, alpha2, iterations2)
print('Final value of theta2 =', theta2)
print('cost_history2 =', cost_history2)
# Out:
# Final value of theta2 = [0.71988473 0.56390334]
# cost_history2 = [5.29831663 5.09909109 4.92356115 ... 3.5993997  3.59939955 3.5993994 ]

# %%
def gradient_descent3(X3, y, theta3, alpha3, iterations3):

    m = len(y)  # Number of training examples
    cost_history3 = np.zeros(iterations3)

    for i in range(iterations3):
        predictions3 = X3.dot(theta3)
        errors3 = np.subtract(predictions3, y)
        sum_delta3 = (alpha3 / m) * X3.transpose().dot(errors3)
        theta3 -= sum_delta3
        cost_history3[i] = compute_cost3(X3, y, theta3)

    return theta3, cost_history3

# %%
theta3 = [0., 0.]
iterations3 = 1500
alpha3 = 0.01

# %%
theta3, cost_history3 = gradient_descent3(X3, y, theta3, alpha3, iterations3)
print('Final value of theta3 =', theta3)
print('cost_history3 =', cost_history3)
# Out:
# Final value of theta3 = [ 2.78048129 -0.48451631]
# cost_history3 = [5.40768785 5.30397076 5.21178297 ... 3.63053597 3.6305311  3.63052625]

# %%
# Assuming that X1, y, and theta are already defined
# Also assuming that X1 has two columns: a feature column and a column of ones

# Scatter plot for the training data (X1)
plt.scatter(X1[:, 1], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model (X1)
plt.plot(X1[:, 1], X1.dot(theta1), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('X1')
plt.ylabel('Y')
plt.title('Linear Regression Fit 0.01 Alpha (X1)')
plt.legend()

# Show the plot
plt.show()
print('')

# Scatter plot for the training data (X2)
plt.scatter(X2[:, 1], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model (X2)
plt.plot(X2[:, 1], X2.dot(theta2), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('X2')
plt.ylabel('Y')
plt.title('Linear Regression Fit 0.01 Alpha (X2)')
plt.legend()

# Show the plot
plt.show()
print('')

# Scatter plot for the training data (X3)
plt.scatter(X3[:, 1], y, color='red', marker='+', label='Training Data')

# Line plot for the linear regression model (X3)
plt.plot(X3[:, 1], X3.dot(theta3), color='green', label='Linear Regression')

# Plot customizations
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)
plt.xlabel('X3')
plt.ylabel('Y')
plt.title('Linear Regression Fit 0.01 Alpha (X3)')
plt.legend()

# Show the plot
plt.show()
print('')

# %%
plt.plot(range(1, iterations1 + 1), cost_history1, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent 0.01 Alpha (X1)')

# Show the plot
plt.show()
print('')



plt.plot(range(1, iterations2 + 1), cost_history2, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent 0.01 Alpha (X2)')

# Show the plot
plt.show()
print('')

plt.plot(range(1, iterations3 + 1), cost_history3, color='blue')
plt.rcParams["figure.figsize"] = (10, 6)
plt.grid(True)

plt.xlabel('Number of iterations')
plt.ylabel('Cost (J)')
plt.title('Convergence of gradient descent 0.01 Alpha (X3)')

# Show the plot
plt.show()
print('')
